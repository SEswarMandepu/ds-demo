# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/SEswarMandepu/ds-demo/main/mock_dataset.csv")

# %%
df
# Out:
#      id first_name   last_name                           email  \
# 0   235     Lexine      Daouse             ldaouse0@ebay.co.uk
# 1   236    Romonda    Eberlein        reberlein1@angelfire.com
# 2   237     Joanie        Khan            jkhan2@mediafire.com
# 3   238     Joelly     Neising           jneising3@dedecms.com
# 4   239    Wilfrid     Bifield          wbifield4@engadget.com
# ..  ...        ...         ...                             ...
# 95  330    Arleyne  Dassindale     adassindale2n@123-reg.co.uk
# 96  331     Bertie    Pannaman  bpannaman2o@huffingtonpost.com
# 97  332       Luis    Apedaile       lapedaile2p@goodreads.com
# 98  333      Minor     Manueli          mmanueli2q@answers.com
# 99  334      Homer      Cadany               hcadany2r@ibm.com
#
#          ip_address
# 0     240.12.57.166
# 1    218.58.197.224
# 2     161.5.165.102
# 3     236.85.227.55
# 4    93.178.125.245
# ..              ...
# 95   188.186.113.21
# 96   149.171.15.200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   first_name  100 non-null    object
#  2   last_name   100 non-null    object
#  3   email       100 non-null    object
#  4   ip_address  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#                id
# count  100.000000
# mean   284.500000
# std     29.011492
# min    235.000000
# 25%    259.750000
# 50%    284.500000
# 75%    309.250000
# max    334.000000
